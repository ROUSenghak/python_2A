# %%
import pandas as pd

# %%
import requests

url = "https://www.insee.fr/fr/statistiques/fichier/6800675/v_commune_2023.csv"
url_backup = "https://minio.lab.sspcloud.fr/lgaliana/data/python-ENSAE/cog_2023.csv"

try:
    response = requests.get(url)
except requests.exceptions.RequestException as e:
    print(f"Error : {e}")
    response = requests.get(url_backup)

# Only download if one of the request succeeded
if response.status_code == 200:
    with open("cog_2023.csv", "wb") as file:
        file.write(response.content)


df = pd.read_csv("cog_2023.csv")

df
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37558     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37559     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37560     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37561     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37562     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# ...

# %%
#exo1
#1

url = "https://koumoul.com/s/data-fair/api/v1/datasets/igt-pouvoir-de-rechauffement-global/convert"

emissions = pd.read_csv(url)

emissions
# Out:
#       INSEE commune                  Commune  Agriculture  Autres transports  \
# 0             01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1             01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2             01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3             01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4             01006                  AMBLEON   448.966808                NaN
# ...             ...                      ...          ...                ...
# 35793         95676       VILLERS-EN-ARTHIES  1628.065094                NaN
# 35794         95678            VILLIERS-ADAM   698.630772                NaN
# 35795         95680          VILLIERS-LE-BEL   107.564967                NaN
# 35796         95682          VILLIERS-LE-SEC  1090.890170                NaN
# 35797         95690      WY-DIT-JOLI-VILLAGE  1495.103542                NaN
#
# ...

# %%
#2
display(emissions.head(10))

display(emissions.tail(15))

display(emissions.sample(10, random_state=42))
# Setting random_state=42 makes the random selection reproducible,
# so you'll always get the same 10 rows every time you run the code. (can use any integer beside 42-just by default-the idea is to fix the generated sample each running)
# Out:
#   INSEE commune                  Commune  Agriculture  Autres transports  \
# 0         01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 1         01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 2         01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 3         01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 4         01006                  AMBLEON   448.966808                NaN
# 5         01007                 AMBRONAY  4390.996698         132.968268
# 6         01008                 AMBUTRIX   489.648726          60.233517
# 7         01009         ANDERT-ET-CONDON   676.468367                NaN
# 8         01010                ANGLEFORT  1070.411510         143.815664
# 9         01011                 APREMONT  2010.790441                NaN
#
#    Autres transports international  CO2 biomasse hors-total      Déchets  \
# 0                              NaN               432.751835   101.430476
# ...

# %%
#3
display(emissions.sample(frac=0.05))
# Out:
#       INSEE commune             Commune  Agriculture  Autres transports  \
# 16965         45085   CHATILLON-COLIGNY  3896.990437         496.853176
# 31475         78358    MAISONS-LAFFITTE   187.009341         625.523287
# 15045         39107            CHARCIER  1143.573649                NaN
# 15211         39288             LAVIGNY  1487.774403           3.117229
# 13551         35001              ACIGNE  7953.647766                NaN
# ...             ...                 ...          ...                ...
# 21452         56262                BONO   369.090763          26.179029
# 30781         76710         TREMAUVILLE  1047.523304                NaN
# 3709          11089     CENNE-MONESTIES   616.497883                NaN
# 16969         45089               CHECY   330.363871         163.854662
# 84            01092  CHATILLON-LA-PALUD   718.152763                NaN
#
#        Autres transports international  CO2 biomasse hors-total     Déchets  \
# ...

# %%
#4
emissions.head(10).sample(n=100, replace=True)
# Out:
#    INSEE commune                  Commune  Agriculture  Autres transports  \
# 0          01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 3          01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 3          01005      AMBERIEUX-EN-DOMBES  1859.160954                NaN
# 2          01004        AMBERIEU-EN-BUGEY   499.043526         212.577908
# 7          01009         ANDERT-ET-CONDON   676.468367                NaN
# ..           ...                      ...          ...                ...
# 6          01008                 AMBUTRIX   489.648726          60.233517
# 1          01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
# 5          01007                 AMBRONAY  4390.996698         132.968268
# 6          01008                 AMBUTRIX   489.648726          60.233517
# 1          01002    L'ABERGEMENT-DE-VAREY   475.330205                NaN
#
#     Autres transports international  CO2 biomasse hors-total      Déchets  \
# ...

# %%
#5
emissions.head(6).sample(n=100, replace=True, weights=[0.5]+[0.1]*5)
# Out:
#    INSEE commune                  Commune  Agriculture  Autres transports  \
# 5          01007                 AMBRONAY  4390.996698         132.968268
# 5          01007                 AMBRONAY  4390.996698         132.968268
# 0          01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 0          01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 0          01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# ..           ...                      ...          ...                ...
# 4          01006                  AMBLEON   448.966808                NaN
# 4          01006                  AMBLEON   448.966808                NaN
# 0          01001  L'ABERGEMENT-CLEMENCIAT  3711.425991                NaN
# 5          01007                 AMBRONAY  4390.996698         132.968268
# 4          01006                  AMBLEON   448.966808                NaN
#
#     Autres transports international  CO2 biomasse hors-total      Déchets  \
# ...
